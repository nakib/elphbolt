# %%
import matplotlib.pyplot as plt

# %%
a = 1
# a = 1
def grad_real(x): 
    return -np.sin(2*x*a)*a

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('data.dat')
plt.plot(data[:,0]/(2*np.pi), data[:,1], label = "calculated")
plt.plot(data[:,0]/(2*np.pi), grad_real(data[:,0]), label = "real")
plt.xlabel("$k_x/2\pi$")
plt.ylabel("$J_{11}$")
plt.legend()
plt.show()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_28695/548954803.py:7: SyntaxWarning: invalid escape sequence '\p'
#   plt.xlabel("$k_x/2\pi$")

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('data_graph.dat')
data_corr = np.loadtxt('correct_graph.dat')

plt.plot(data[:,0]/(2*np.pi), data[:,1], label = "calculated")
plt.plot(data_corr[:,0]/(2*np.pi), data_corr[:,1], label = "data_corr")

# plt.plot(data[:,0]/(2*np.pi), grad_real(data[:,0]), label = "real")
plt.xlabel("$k_x/2\pi$")
plt.ylabel("$J_{11}$")
plt.legend()
plt.show()
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\p'
# <>:11: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_28695/1737357278.py:11: SyntaxWarning: invalid escape sequence '\p'
#   plt.xlabel("$k_x/2\pi$")

# %%
max(data[:,1]-data_corr[:,1])
# Out:
# 0.013793698366941776

# %%
data_corr[:,0]/(2*np.pi)
# Out:
# array([0.   , 0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008,
#        0.009, 0.01 , 0.011, 0.012, 0.013, 0.014, 0.015, 0.016, 0.017,
#        0.018, 0.019, 0.02 , 0.021, 0.022, 0.023, 0.024, 0.025, 0.026,
#        0.027, 0.028, 0.029, 0.03 , 0.031, 0.032, 0.033, 0.034, 0.035,
#        0.036, 0.037, 0.038, 0.039, 0.04 , 0.041, 0.042, 0.043, 0.044,
#        0.045, 0.046, 0.047, 0.048, 0.049, 0.05 , 0.051, 0.052, 0.053,
#        0.054, 0.055, 0.056, 0.057, 0.058, 0.059, 0.06 , 0.061, 0.062,
#        0.063, 0.064, 0.065, 0.066, 0.067, 0.068, 0.069, 0.07 , 0.071,
#        0.072, 0.073, 0.074, 0.075, 0.076, 0.077, 0.078, 0.079, 0.08 ,
#        0.081, 0.082, 0.083, 0.084, 0.085, 0.086, 0.087, 0.088, 0.089,
#        0.09 , 0.091, 0.092, 0.093, 0.094, 0.095, 0.096, 0.097, 0.098,
#        0.099, 0.1  , 0.101, 0.102, 0.103, 0.104, 0.105, 0.106, 0.107,
#        0.108, 0.109, 0.11 , 0.111, 0.112, 0.113, 0.114, 0.115, 0.116,
# ...

# %%
max(data[:,1]-data_corr[:,1])
# Out:
# 3.2898616392773583e-06

# %%
data[299,1]
# Out:
# -0.23848127035542258

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('data_graph_ind.dat')
data_corr = np.loadtxt('correct_graph_ind.dat')

plt.plot(data[:,0]/(2*np.pi), data[:,1], label = "calculated", marker='o',    # Маркер в виде кружков
         linestyle='none')
plt.plot(data_corr[:,0]/(2*np.pi), data_corr[:,1], label = "data_corr", marker='o',    # Маркер в виде кружков
         linestyle='none')

# plt.plot(data[:,0]/(2*np.pi), grad_real(data[:,0]), label = "real")
plt.xlabel("$k_x/2\pi$")
plt.ylabel("$J_{11}$")
plt.legend()
plt.show()
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\p'
# <>:13: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_28695/2407121182.py:13: SyntaxWarning: invalid escape sequence '\p'
#   plt.xlabel("$k_x/2\pi$")
