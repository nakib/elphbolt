# %%
import matplotlib.pyplot as plt

# %%
a = 30
# a = 1
def grad_real(x): 
    return -np.sin(2*x*a)*a

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('data.dat')
plt.plot(data[9900:,0]/(2*np.pi), data[9900:,1], label = "calculated")
plt.plot(data[9900:,0]/(2*np.pi), grad_real(data[9900:,0]), label = "real")
plt.xlabel("$k_x/2\pi$")
plt.ylabel("$J_{11}$")
plt.legend()
plt.show()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_28695/2467438884.py:7: SyntaxWarning: invalid escape sequence '\p'
#   plt.xlabel("$k_x/2\pi$")
